# %%
import numpy as np
from   numpy import exp,cos,sin,pi,tan,sqrt,angle,absolute,eye,dot
import matplotlib.pyplot as plt
from DeDist import dedist
from __future__ import division
import dill
import seaborn.apionly as sns
# Out:
# /home/parallels/miniconda2/envs/msc/lib/python2.7/site-packages/seaborn/apionly.py:6: UserWarning: As seaborn no longer sets a default style on import, the seaborn.apionly module is deprecated. It will be removed in a future version.
#   warnings.warn(msg, UserWarning)

# %%
# Get objects from notebook
dill.load_session('session_states/session_state_het_wid.pkl')

# %% [markdown]
# ### Plot - Bias vs Encoded angle

# %%
plt.figure(figsize=(4,3))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)
plt.rc('axes', labelsize=14)

plt.plot(THETAS, ests_hom_3[1], label='Homogeneous')
plt.plot(THETAS, ests_het_truncnorm_s014[1], label='$\sigma=0.14$')
plt.plot(THETAS, ests_het_truncnorm_s020[1], label='$\sigma=0.2$')
plt.plot(THETAS, ests_het_truncnorm_s037[1], label='$\sigma=0.37$')
plt.plot(THETAS, ests_het_truncnorm_s092[1], label='$\sigma=0.92$')

plt.legend()
plt.xlabel('Encoded angle $\Theta$')
plt.ylabel('Bias (rad)')
plt.tick_params(direction='in', top='on', right='on')

plt.show()
# plt.savefig('new_plots/3_het/bias_wid.pdf', format='pdf', bbox_inches='tight')

plt.close()

# %% [markdown]
# ### Plot - Variance vs Correlation length

# %%
plt.figure(figsize=(4,3))

plt.rc('text', usetex=True)
plt.rc('font', family='serif')
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)
plt.rc('axes', labelsize=14)

plt.plot(THETAS, ests_hom_3[2], label='Homogeneous')
plt.plot(THETAS, ests_het_truncnorm_s014[2], label='$\sigma=0.14$')
plt.plot(THETAS, ests_het_truncnorm_s020[2], label='$\sigma=0.2$')
plt.plot(THETAS, ests_het_truncnorm_s037[2], label='$\sigma=0.37$')
plt.plot(THETAS, ests_het_truncnorm_s092[2], label='$\sigma=0.92$')

plt.legend()
plt.xlabel('Encoded angle $\Theta$')
plt.ylabel('Estimator variance')
plt.tick_params(direction='in', top='on', right='on')

plt.show()
# plt.savefig('new_plots/3_het/var_wid.pdf', format='pdf', bbox_inches='tight')

plt.close()
